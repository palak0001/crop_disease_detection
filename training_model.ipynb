# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
SEED = 42
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 25

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %%
DATASET_PATH = "dataset/plant_disease"

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

class_names = train_ds.class_names
num_classes = len(class_names)

print("Classes:", class_names)
# Out:
# Found 20638 files belonging to 15 classes.
# Using 16511 files for training.
# Found 20638 files belonging to 15 classes.
# Using 4127 files for validation.
# Classes: ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_Late_blight', 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Target_Spot', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato__Tomato_mosaic_virus', 'Tomato_healthy']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.shuffle(1000).prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
])

# %%
base_model = tf.keras.applications.EfficientNetB0(
    input_shape=IMG_SIZE + (3,),
    include_top=False,
    weights="imagenet"
)

base_model.trainable = False  # transfer learning first

# %%
inputs = keras.Input(shape=IMG_SIZE + (3,))
x = data_augmentation(inputs)
x = tf.keras.applications.efficientnet.preprocess_input(x)

x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.4)(x)

outputs = layers.Dense(num_classes, activation="softmax")(x)

model = keras.Model(inputs, outputs)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 15)             │         3,855 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,386,482 (16.73 MB)
#  Trainable params: 334,351 (1.28 MB)
#  Non-trainable params: 4,052,131 (15.46 MB)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=5,
        restore_best_weights=True
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.3,
        patience=3
    )
]

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
    
)
# Out:
# Epoch 1/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 825s 1s/step - accuracy: 0.8078 - loss: 0.6132 - val_accuracy: 0.9244 - val_loss: 0.2217 - learning_rate: 0.0010
# Epoch 2/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 850s 2s/step - accuracy: 0.8951 - loss: 0.3177 - val_accuracy: 0.9334 - val_loss: 0.1901 - learning_rate: 0.0010
# Epoch 3/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 564s 1s/step - accuracy: 0.9090 - loss: 0.2761 - val_accuracy: 0.9307 - val_loss: 0.2199 - learning_rate: 0.0010
# Epoch 4/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 543s 1s/step - accuracy: 0.9184 - loss: 0.2375 - val_accuracy: 0.9586 - val_loss: 0.1239 - learning_rate: 0.0010
# Epoch 5/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 582s 1s/step - accuracy: 0.9284 - loss: 0.2152 - val_accuracy: 0.9508 - val_loss: 0.1410 - learning_rate: 0.0010
# Epoch 6/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 564s 1s/step - accuracy: 0.9313 - loss: 0.2083 - val_accuracy: 0.9448 - val_loss: 0.1642 - learning_rate: 0.0010
# Epoch 7/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 553s 1s/step - accuracy: 0.9328 - loss: 0.2018 - val_accuracy: 0.9498 - val_loss: 0.1458 - learning_rate: 0.0010
# Epoch 8/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 541s 1s/step - accuracy: 0.9512 - loss: 0.1495 - val_accuracy: 0.9656 - val_loss: 0.1069 - learning_rate: 3.0000e-04
# Epoch 9/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 547s 1s/step - accuracy: 0.9563 - loss: 0.1263 - val_accuracy: 0.9661 - val_loss: 0.1063 - learning_rate: 3.0000e-04
# Epoch 10/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 550s 1s/step - accuracy: 0.9601 - loss: 0.1161 - val_accuracy: 0.9656 - val_loss: 0.0991 - learning_rate: 3.0000e-04
# Epoch 11/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 538s 1s/step - accuracy: 0.9595 - loss: 0.1177 - val_accuracy: 0.9680 - val_loss: 0.0938 - learning_rate: 3.0000e-04
# Epoch 12/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 542s 1s/step - accuracy: 0.9623 - loss: 0.1099 - val_accuracy: 0.9658 - val_loss: 0.0989 - learning_rate: 3.0000e-04
# Epoch 13/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 539s 1s/step - accuracy: 0.9623 - loss: 0.1039 - val_accuracy: 0.9707 - val_loss: 0.0938 - learning_rate: 3.0000e-04
# Epoch 14/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 539s 1s/step - accuracy: 0.9652 - loss: 0.1010 - val_accuracy: 0.9649 - val_loss: 0.0980 - learning_rate: 3.0000e-04
# Epoch 15/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 544s 1s/step - accuracy: 0.9674 - loss: 0.0943 - val_accuracy: 0.9685 - val_loss: 0.0903 - learning_rate: 9.0000e-05
# Epoch 16/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 549s 1s/step - accuracy: 0.9678 - loss: 0.0906 - val_accuracy: 0.9692 - val_loss: 0.0904 - learning_rate: 9.0000e-05
# Epoch 17/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 545s 1s/step - accuracy: 0.9677 - loss: 0.0929 - val_accuracy: 0.9700 - val_loss: 0.0863 - learning_rate: 9.0000e-05
# Epoch 18/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 540s 1s/step - accuracy: 0.9706 - loss: 0.0871 - val_accuracy: 0.9683 - val_loss: 0.0899 - learning_rate: 9.0000e-05
# Epoch 19/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 545s 1s/step - accuracy: 0.9713 - loss: 0.0839 - val_accuracy: 0.9685 - val_loss: 0.0882 - learning_rate: 9.0000e-05
# Epoch 20/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 543s 1s/step - accuracy: 0.9726 - loss: 0.0821 - val_accuracy: 0.9707 - val_loss: 0.0805 - learning_rate: 9.0000e-05
# Epoch 21/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 544s 1s/step - accuracy: 0.9721 - loss: 0.0800 - val_accuracy: 0.9719 - val_loss: 0.0821 - learning_rate: 9.0000e-05
# Epoch 22/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 550s 1s/step - accuracy: 0.9738 - loss: 0.0787 - val_accuracy: 0.9702 - val_loss: 0.0807 - learning_rate: 9.0000e-05
# Epoch 23/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 545s 1s/step - accuracy: 0.9706 - loss: 0.0838 - val_accuracy: 0.9709 - val_loss: 0.0794 - learning_rate: 9.0000e-05
# Epoch 24/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 546s 1s/step - accuracy: 0.9739 - loss: 0.0765 - val_accuracy: 0.9726 - val_loss: 0.0798 - learning_rate: 9.0000e-05
# Epoch 25/25
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 547s 1s/step - accuracy: 0.9743 - loss: 0.0740 - val_accuracy: 0.9712 - val_loss: 0.0787 - learning_rate: 9.0000e-05

# %%
model.save("plant_disease_model.keras")
